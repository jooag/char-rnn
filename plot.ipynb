# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
train_history=torch.load('checkpoints/train_hist.pth')
loss = train_history['loss_hist']

n=train_history['batches_per_epoch']
e = train_history['num_epochs']
print(e)
#plt.vlines([n* i for i in range(e+2)], ymin=0, ymax=np.max(loss), linestyles='dotted',color='red', lw=.5)
tests = train_history['test_hist']

plt.plot(loss, lw=1)
plt.plot(train_history['test_points']), tests, color='green', marker='o', ms=3, lw=0.3)

print(tests)
# Out:
# 9
# [1.118116489103285, 1.1233161469637334, 1.1250576087983997, 1.1103748984256039, 1.1086944673020964, 1.1071918725967411, 1.1137557478274338]
